# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
df= pd.read_json('Digital_Music_5.json', lines=True)

# %%
df.head()
# Out:
#    overall  vote  verified   reviewTime      reviewerID        asin  \
# 0        5   3.0      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1        5   NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2        5   NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3        4   3.0     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4        5   NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 3  {'Format:': ' Audio CD'}  john F&#039;n doe
# 4  {'Format:': ' Audio CD'}  melinda a goodman
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# ...

# %%
df.shape
# Out:
# (169781, 12)

# %%
missing_values_count = df.isnull()

# %%
missing_values_count.sum()
# Out:
# overall                0
# vote              162170
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style              11792
# reviewerName           5
# reviewText           158
# summary               36
# unixReviewTime         0
# image             169599
# dtype: int64

# %%
df.describe()
# Out:
#              overall         vote  unixReviewTime
# count  169781.000000  7611.000000    1.697810e+05
# mean        4.700019     7.920641    1.416789e+09
# std         0.713420    18.625143    6.188641e+07
# min         1.000000     2.000000    8.999424e+08
# 25%         5.000000     2.000000    1.386893e+09
# 50%         5.000000     3.000000    1.421712e+09
# 75%         5.000000     6.000000    1.455062e+09
# max         5.000000   461.000000    1.537920e+09

# %%
df['reviewerID'].nunique()
# Out:
# 16566

# %%
#Avg number of reviews per reviewerID
df['reviewerID'].value_counts().sum()/df['reviewerID'].nunique()
# Out:
# 10.248762525654955

# %%
10.248762525654955*16566
# Out:
# 169781.0

# %%
df['reviewerID'].value_counts().head(40)
# Out:
# A3W4D8XOGLWUN5    791
# A2H3JURQZOHVMB    314
# A36EDWL4F3AASU    223
# A165P3MOJV3OVZ    219
# AVKHYC2D7MD56     214
# A237E0FTADYM58    189
# AMP7TQRWAIE84     185
# A14YTPQDH3PAZU    165
# A15T3Y3BL2AJ9V    157
# A2KW2KWKABNYNO    149
# A3VWZMMIKPY2XU    143
# A1BVCH82W0M2W2    137
# A2ABJ4XM4MJ5CD    134
# A1OKPC1K12YZEP    131
# ASFQBB524HVRJ     130
# A1GN8UJIZLCA59    128
# A9Q28YTLYREO7     126
# A2LDEDOQZH3VTP    126
# A2UQGX6YMQ5BAL    124
# A2JMRUN0QULNLI    123
# A10M52OJSDB8WK    121
# A2LTPIQG2RWNJW    121
# AAT1JT5M65VGQ     121
# A3GJ6CFWN47N0U    120
# A1RGJA7LQ3B5H7    116
# A2PR1O53J0V8W2    110
# A3KQI694I9KL5L    108
# A3W527BN42AXN1    108
# ARYVQL4N737A1     107
# A3BIV1X1K9R796    107
# A1M3F4G45OXRDI    107
# A15JTJXQXO22JJ    107
# A22PZBENWG6IM0    106
# A2UYBXJACYG1N9    104
# ABDR6IJ93HFIO     104
# A2UFJ5NIT2RFCM    103
# A2RNYF2PTOB82J    102
# A2TTBO023PYYBA    101
# A135GWMXMTR58Z    100
# AARHFHP17QFNG      98
# Name: reviewerID, dtype: int64

# %%
df.drop(['vote', 'image'], axis = 1, inplace = True)

# %%
df.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1        5      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2        5      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3        4     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4        5      True  06 12, 2016  A3OH43OZJLKI09  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 3  {'Format:': ' Audio CD'}  john F&#039;n doe
# 4  {'Format:': ' Audio CD'}  melinda a goodman
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# 3  well best of's are a bit poison normally but t...
# ...

# %%
df['verified'].value_counts()
# Out:
# True     148944
# False     20837
# Name: verified, dtype: int64

# %%
super_user = df.loc[df['reviewerID'] == 'A3W4D8XOGLWUN5', :]

# %%
super_user['verified'].value_counts()
# Out:
# False    766
# True      25
# Name: verified, dtype: int64

# %%
df['style'].value_counts()
# Out:
# {'Format:': ' MP3 Music'}         146766
# {'Format:': ' Audio CD'}           10815
# {'Format:': ' Vinyl'}                345
# {'Format:': ' DVD'}                   26
# {'Format:': ' Audio Cassette'}        14
# {'Format:': ' Blu-ray Audio'}          8
# {'Format:': ' Blu-ray'}                7
# {'Format:': ' Vinyl Bound'}            4
# {'Format:': ' Amazon Video'}           3
# {'Format:': ' DVD Audio'}              1
# Name: style, dtype: int64

# %%
five_stars = df.loc[df['overall'] == 5, :]

# %%
five_stars.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1        5      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2        5      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 4        5      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# 6        5      True   06 6, 2015  A20Z0JD766DPG6  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 4  {'Format:': ' Audio CD'}  melinda a goodman
# 6  {'Format:': ' Audio CD'}           M Holley
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# 4  What can I say? This is Casting Crowns!!!This ...
# ...

# %%
Non_v_five_stars = five_stars[five_stars['verified']== False]

# %%
five_stars['totalwords'] = five_stars['reviewText'].str.count(' ') + 1
# Out:
# <ipython-input-64-40bad7b206ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   five_stars['totalwords'] = five_stars['reviewText'].str.count(' ') + 1

# %%
five_stars.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1        5      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2        5      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 4        5      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# 6        5      True   06 6, 2015  A20Z0JD766DPG6  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 4  {'Format:': ' Audio CD'}  melinda a goodman
# 6  {'Format:': ' Audio CD'}           M Holley
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# 4  What can I say? This is Casting Crowns!!!This ...
# ...

# %%
df['totalwords'] = df['reviewText'].str.count(' ') + 1

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1        5      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2        5      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3        4     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4        5      True  06 12, 2016  A3OH43OZJLKI09  5557706259
#
#                       style       reviewerName  \
# 0  {'Format:': ' Audio CD'}            Garrett
# 1  {'Format:': ' Audio CD'}                 Ad
# 2  {'Format:': ' Audio CD'}             JTGabq
# 3  {'Format:': ' Audio CD'}  john F&#039;n doe
# 4  {'Format:': ' Audio CD'}  melinda a goodman
#
#                                           reviewText  \
# 0  This is awesome to listen to, A must-have for ...
# 1                                               bien
# 2  It was great to hear the old stuff again and I...
# 3  well best of's are a bit poison normally but t...
# ...

# %%
bots = df.loc[df['totalwords'] == 4, :]

# %%
bots.head(10)
# Out:
#      overall  verified   reviewTime      reviewerID        asin  \
# 89         5      True   03 4, 2018   AD6G80D2PS6UG  9714721180
# 104        5      True  09 30, 2015  A27TQ6L6C4XTYF  9714721180
# 309        5      True  10 16, 2015   AHM0BJW4T0DNB  B000QNVB5E
# 322        5      True   07 1, 2015  A1ZERSCNHJTGRR  B000QNZNNA
# 328        5      True  07 28, 2014   AR8O7SVSEUI9Z  B000QNZNNA
# 386        5      True  10 15, 2014  A34QG0XEVSBIIH  B000QON8M2
# 435        5      True  09 17, 2015  A1L0T3KRHRRYPM  B000QP6SVY
# 444        5      True  07 15, 2014  A2DY7N9SKROB5I  B000QP6SVY
# 493        5      True  05 24, 2015  A3G6F9P47FPCIG  B000QPL8QE
# 515        5      True  08 28, 2014  A3DPVXS7PH5RTF  B000QVL4NU
#
#                          style       reviewerName  \
# 89   {'Format:': ' MP3 Music'}                Rae
# 104   {'Format:': ' Audio CD'}        Marvin Horn
# 309  {'Format:': ' MP3 Music'}  Educated Consumer
# 322  {'Format:': ' MP3 Music'}               Lolo
# ...

# %%
super_user.head(10)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 24          4     False  07 19, 2005  A3W4D8XOGLWUN5  7799420340
# 68          4     False  12 25, 2009  A3W4D8XOGLWUN5  7799420340
# 797         5     False  12 23, 2014  A3W4D8XOGLWUN5  B000S52E9W
# 897         5     False   07 2, 2015  A3W4D8XOGLWUN5  B000S55TTY
# 985         4     False  01 25, 2014  A3W4D8XOGLWUN5  B000SX87C2
# 1854        5     False  02 12, 2016  A3W4D8XOGLWUN5  B000T31G8S
# 1855        5     False   01 1, 2016  A3W4D8XOGLWUN5  B000T31G8S
# 2415        4     False  05 11, 2012  A3W4D8XOGLWUN5  B000TE0O7G
# 3744        5     False  03 28, 2016  A3W4D8XOGLWUN5  B000V61B4M
# 4861        5     False  03 28, 2016  A3W4D8XOGLWUN5  B000V68RZI
#
#                           style    reviewerName  \
# 24     {'Format:': ' Audio CD'}  Michael Kerner
# 68    {'Format:': ' MP3 Music'}  Michael Kerner
# 797   {'Format:': ' MP3 Music'}  Michael Kerner
# 897   {'Format:': ' MP3 Music'}  Michael Kerner
# ...

# %%
super_user['reviewText'].nunique()
# Out:
# 715

# %%
vinyl = df.loc[df['style'] == 'Vinyl', :]

# %%
vinyl.head(25)
# Out:
# Empty DataFrame
# Columns: [overall, vote, verified, reviewTime, reviewerID, asin, style, reviewerName, reviewText, summary, unixReviewTime, image]
# Index: []

# %%
from nltk.tokenize import sent_tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.stem.porter import PorterStemmer

# %%
from nltk.stem.lancaster import LancasterStemmer

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
from nltk.stem import WordNetLemmatizer

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.nlp.ex1 import *
print('Setup Complete')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-7da73b352cf6> in <module>
# ----> 1 from learntools.core import binder
#       2 binder.bind(globals())
#       3 from learntools.nlp.ex1 import *
#       4 print('Setup Complete')
#
# ModuleNotFoundError: No module named 'learntools'
